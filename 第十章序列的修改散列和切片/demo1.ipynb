# %%
# 切片原理
class MySeq:
    def __getitem__(self, index):
        return index

# %%
s = MySeq()
s[1]
# Out:
# 1

# %%
s[1:3]
# Out:
# slice(1, 3, None)

# %%
s[1:3:2]
# Out:
# slice(1, 3, 2)

# %%
s[1:2:2,5]
# Out:
# (slice(1, 2, 2), 5)

# %%
s[1:2:2,5:6]
# Out:
# (slice(1, 2, 2), slice(5, 6, None))
