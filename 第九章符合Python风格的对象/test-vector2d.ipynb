# %%
from vector2d_v0 import Vector2d

# %%
v1 = Vector2d(3, 4)
v1
# Out:
# Vector2d(3.0, 4.0)

# %%
v1.x
# Out:
# 3.0

# %%
v1_clone = eval(repr(v1))
v1_clone == v1
# Out:
# True

# %%
print(v1_clone)
# Out:
# (3.0, 4.0)
