# %%
def deco(func):
    def inner():
        print("inner running")
    return inner
@deco
def func():
    print("func running")

# %%
func()
# Out:
# inner running

# %%
func
# Out:
# <function __main__.deco.<locals>.inner()>
