# %%
def f(a, b):
    print(id(a))
    a += b
    print(id(a))
    return a

# %%
m = [1, 2]
n = [3, 4]
f(m, n)
# Out:
# 2144041542720
# 2144041542720
# [1, 2, 3, 4]

# %%
m = (1, 2)
n = (3, 4)
f(m, n)
# Out:
# 2144041617792
# 2144041381184
# (1, 2, 3, 4)
